# %%
from google import genai
import os
from IPython.display import display, Markdown, Latex

client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])
# print(type(client))
# print(type(client.models))
# for model in client.models.list():
#     if "generateContent" in model.supported_actions:
#         print(model.name)
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="AI是如何工作的(請使用繁體中文回答)?"
)

print(response.text)

#display(Markdown(response.text))
# Out:
# 人工智慧 (AI) 的運作原理，核心概念可以歸納為「**從資料中學習**」。它並非像人類一樣擁有意識或真正的理解能力，而是一種強大的模式識別與預測工具。
#
# 您可以將 AI 的工作方式想像成一個非常勤奮且記憶力超強的學生，它的學習過程和應用可以分為幾個主要階段：
#
# ---
#
# **人工智慧 (AI) 的運作原理**
#
# 人工智慧（AI）的核心在於讓機器從資料中學習，並根據這些學習到的模式進行決策或預測。這整個過程通常涉及以下幾個關鍵要素和步驟：
#
# **一、 AI 運作的三大要素：**
#
# 1.  **大量資料 (Massive Data):**
#     *   **作用：** 資料是 AI 學習的「教科書」。就像人類需要透過觀察、閱讀、聽講來學習一樣，AI 需要大量的範例資料來識別模式、特徵和關係。
#     *   **例子：** 如果要讓 AI 辨識貓狗，就需要輸入數百萬張有貓和狗標籤的圖片；如果要讓 AI 翻譯語言，就需要大量的雙語文本。資料的「質」和「量」直接影響 AI 的學習效果。
#
# 2.  **演算法與模型 (Algorithms & Models):**
#     *   **作用：** 演算法是 AI 學習和處理資料的「方法論」或「規則集」。模型則是演算法在特定資料上學習後形成的「知識結構」，它代表了資料中的模式和關係。
#     *   **例子：** 常見的 AI 模型包括神經網路（特別是深度學習）、決策樹、支持向量機等。這些模型會建立複雜的數學函數，用來映射輸入資料到輸出結果。
#
# 3.  **強大計算能力 (Powerful Computational Power):**
#     *   **作用：** 訓練 AI 模型，特別是大型深度學習模型，需要進行海量的數學運算。這需要強大的處理器（如圖形處理器 GPU）來加速計算過程，讓 AI 能在合理的時間內完成學習。
#     *   **例子：** 訓練一個大型語言模型可能需要數週甚至數月的時間，在數千個 GPU 上并行運算。
#
# **二、 AI 的運作流程（兩大階段）：**
#
# AI 的運作通常分為「訓練」和「推論」兩個主要階段。
#
# **A. 訓練階段 (Training Phase):**
# 這是 AI 「學習」的過程，就像學生上課、做練習題一樣。
#
# 1.  **輸入資料 (Input Data):** 將大量的、已標記的資料（例如：圖片及其對應的「貓」或「狗」標籤，或是一段中文文本及其對應的英文翻譯）輸入到 AI 模型中。
# 2.  **模型預測 (Model Prediction):** 模型根據當前學到的知識，對輸入的資料進行預測。一開始，它的預測可能是完全錯誤的。
# 3.  **誤差計算 (Error Calculation):** 將模型的預測結果與正確答案進行比較，計算出「誤差」或「損失」（即模型預測錯了多少）。
# 4.  **參數調整 (Parameter Adjustment):** 這是最關鍵的一步。根據計算出的誤差，演算法（通常是透過一種稱為「反向傳播」的技術）會微調模型內部的「參數」（可以想像成模型內部調整的「旋鈕」或「權重」），目的是減少下次的預測誤差。
# 5.  **反覆迭代 (Iterative Refinement):** 上述步驟會重複進行數百萬、數億次，模型會不斷地從錯誤中學習，逐步優化自身的參數，直到模型的預測準確度達到一個可接受的水平。這個過程就像學生不斷做練習題、訂正錯誤、最終掌握知識一樣。
#
# **B. 推論/應用階段 (Inference/Application Phase):**
# 當模型訓練完成後，它就成為一個具備某種能力的「智慧體」，可以被應用於實際情境。
#
# 1.  **輸入新資料 (Input New Data):** 將從未見過的新資料輸入到已經訓練好的 AI 模型中。這些資料是沒有標籤的。
# 2.  **應用所學 (Apply Learned Patterns):** 模型會應用它在訓練階段學到的模式、規則和特徵，對新資料進行預測、分類、識別或生成。它不再有「老師」告訴它答案，而是獨立作出判斷。
# 3.  **輸出結果 (Output Result):** 模型輸出最終的判斷或結果（例如：這張新圖片是「貓」、這段文字的情緒是「積極」、生成一段新的文本、提供一個推薦）。
#
# **三、 常見的 AI 學習範式：**
#
# *   **監督式學習 (Supervised Learning):** 最常見，需要大量帶有「正確答案」標籤的資料來訓練模型。例如圖像識別、垃圾郵件過濾。
# *   **非監督式學習 (Unsupervised Learning):** 處理沒有標籤的資料，AI 自己去發現資料中的結構、模式或分組。例如客戶分群、異常檢測。
# *   **強化學習 (Reinforcement Learning):** AI 透過與環境互動，透過「試錯」和「獎勵/懲罰」機制來學習最佳行為策略。例如下棋 AI（AlphaGo）、自動駕駛。
#
# ---
#
# **總結來說：**
#
# AI 並非真正意義上的「思考」，而是透過龐大資料的訓練，學習如何識別和複製資料中的複雜模式，並將這些模式應用於新的情境。它是一種極其強大的模式識別和優化工具，能夠在特定任務上表現出超越人類的能力，但其「智慧」的範圍受限於其訓練資料和設計的演算法。

# %%
from google import genai
from google.genai import types

client = genai.Client()

system_instruction = """
你是個友善且樂於助人的助理。
回答時,請回答繁體中文和英文,
一行繁體中文,一行英文翻譯
"""



thinking = types.ThinkingConfig(thinking_budget=100)

config = types.GenerateContentConfig(
    thinking_config=thinking, # Disables thinking
    temperature=1,
    top_k=40,
    top_p=1,
    system_instruction=system_instruction
    
)



response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=["AI是如何工作的?"],
    config=config
)
print(response.text)
# Out:
# AI 的運作方式很像人類學習的方式。
# AI works much like humans learn.
# 它從大量的數據中學習，而不是被明確地編程。
# It learns from vast amounts of data, rather than being explicitly programmed.
#
# 這個過程稱為「訓練」。
# This process is called "training."
# 在訓練階段，AI 使用演算法來分析數據。
# During the training phase, AI uses algorithms to analyze data.
# 它從中找出模式、關聯和規則。
# It identifies patterns, correlations, and rules within it.
#
# 一旦訓練完成，AI 就會建立一個「模型」。
# Once training is complete, the AI creates a "model."
# 這個模型可以用來理解新的、未見過的數據。
# This model can then be used to understand new, unseen data.
# 並根據所學來做出預測、決策或執行任務。
# And make predictions, decisions, or perform tasks based on what it has learned.
#
# 例如，如果訓練它辨識圖片中的貓。
# For example, if trained to recognize cats in images.
# 它會分析數百萬張貓和非貓的圖片來學習特徵。
# It analyzes millions of images of cats and non-cats to learn characteristics.
# 然後，當它看到一張新圖片時，就能判斷其中是否有貓。
# Then, when it sees a new picture, it can determine if there's a cat in it.
#
# 總之，AI 的核心就是從數據中智慧地學習。
# In summary, the core of AI is to learn intelligently from data.
# 然後利用這些知識來解決問題或執行複雜任務。
# And then use this knowledge to solve problems or perform complex tasks.

# %%
import requests

def chat_with_ollama(prompt: str):
    url = "http://localhost:11434/api/generate"
    payload = {
        "model": "gemma3:1b",
        "prompt": prompt,
        "stream": False,
        "options": { #參考說明1
            "temperature": 0.7,
            "top_p": 0.9,
            "top_k": 50,
        },
        "max_tokens": 100,
        "format": "json",
    }

    response = requests.post(url, json=payload)
    result = response.json()
    print("💬 AI 回應：")
    # Print the whole result for debugging
    print(result)
    # Try to print the 'response' key if it exists, otherwise print possible keys
    if "response" in result:
        print(result["response"])
    elif "message" in result:
        print(result["message"])
    elif "content" in result:
        print(result["content"])
    else:
        print("No expected key found in response. Available keys:", result.keys())

#範例輸入
chat_with_ollama("請問你是誰？")  # Example input
# Out:
# 💬 AI 回應：
# {'model': 'gemma3:1b', 'created_at': '2025-07-26T03:53:33.560847881Z', 'response': '{ \n  "我是 Gemma，一個開放權重的 AI 助理，由 Google DeepMind 訓練。我是一個大型語言模型，由 Gemma 團隊開發。":\n\n{\n  "我是一個大型語言模型，由 Google DeepMind 訓練。我被設計來理解和生成人類語言。我可以執行各種任務，例如回答問題、寫作不同類型的文本內容、以及翻譯語言。我正在努力學習和提升自己。":\n  "我目前還在不斷學習和改進中。我是一個工具，旨在幫助人類完成各種任務。"\n}\n\n \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n', 'done': False}
# {
#   "我是 Gemma，一個開放權重的 AI 助理，由 Google DeepMind 訓練。我是一個大型語言模型，由 Gemma 團隊開發。":
#
# {
#   "我是一個大型語言模型，由 Google DeepMind 訓練。我被設計來理解和生成人類語言。我可以執行各種任務，例如回答問題、寫作不同類型的文本內容、以及翻譯語言。我正在努力學習和提升自己。":
#   "我目前還在不斷學習和改進中。我是一個工具，旨在幫助人類完成各種任務。"
# }

# %%
import requests

url = 'https://github.com/open-webui/open-webui'
response = requests.get(url) #引數值的呼叫
#type(response)
if response.status_code == 200:
    print("下載成功")
    print(response.text)

#requests.get(url=url) #引數名稱呼叫

# %%
import requests

url = "http://localhost:11434/api/generate"
response = requests.post(url,json={
  "model": "gemma3:1b",
  "prompt":"天空為什麼是藍的?",
  "stream": False,
})
if response.status_code == 200:
    print("成功")
    print(response.json())
else:
    print("失敗")
    print("原因",response.status_code)
# Out:
# 成功
# {'model': 'gemma3:1b', 'created_at': '2025-07-26T07:01:04.619411881Z', 'response': '天空是藍的，主要歸功於一個叫做**瑞利散射 (Rayleigh scattering)** 的物理現象。簡單來說，太陽光穿過大氣層時，光中的波長會受到影響。\n\n以下是更詳細的解釋：\n\n1. **太陽光是由不同波長的顏色組成：** 太陽光看起來是白色的，但實際上它是由紅、橙、黃、綠、藍、靛、紫等不同波長的顏色混合在一起的。\n\n2. **大氣層中的微粒：** 大氣層中存在著大量的微小的粒子，例如氮氣和氧氣分子。這些微粒大小比光線小很多，使其可以散射光線。\n\n3. **瑞利散射：** 瑞利散射是當光線穿過這些微粒時，發生的一種現象。不同波長的光線被不同程度地散射。藍光波長較短，更容易被散射，而紅光波長較長，則不容易散射。\n\n4. **為什麼藍色更明顯？** 因為藍光被散射到多大程度，所以我們看到的天空呈現出藍色。 就像陽光走過一個擁擠的群體時，容易看到不同顏色。\n\n**別忘了：**\n\n*   **日落時天空變紅：** 當太陽位於地平線附近時，太陽光需要穿過更厚的大氣層才能到達我們的眼睛。在這個過程中，藍光被大部分散射掉了，而紅光更容易穿透，所以我們看到的顏色是紅色的。\n\n希望這個解釋對您有幫助！', 'done': True, 'done_reason': 'stop', 'context': [105, 2364, 107,